# %% [markdown]
# # Lab 4 — Submission Setup, and Object Oriented Programming
#
# **This session (Friday 9/11) starts with getting submission working**, then moves to the
# exercises.
#
# Two halves:
#
# 1. **Setting up submission** — fork, clone, wire the remotes, commit, push. We do this together,
#    from scratch. You do not need to have done anything beforehand. **Lab 2 is due tonight and you
#    will submit it here.**
# 2. **The Object Oriented Programming exercises** — the lab itself, which uses the Lectures 8–9
#    material.
#
# `Labs/GitHub-Setup.pdf` is the written version of part 1, with a table of what to do when git
# complains. If you already have authentication working from Lab 3, part 1 will be quick.

# %% [markdown]
# ## Part 1 — Setting up submission (this session)
#
# Our course repository is public. The instructions here aim to have you setup a fork of the course repository. Unfortunately because you are forking a public repo, your fork will have to be public also.
#
# > **The same steps, in a document you can follow line by line, are in
# > `Labs/GitHub-Setup.pdf`.** It covers authentication, the WSL filesystem trap, git identity, the
# > remote setup below, the two errors everyone hits on their first push, and a table of what to do
# > when git complains. If you only read one thing, read that.
#
# You should be familiar with git from the first semester of this course. I assume that you all have github accounts and have setup things to be able to [push to github using ssh](https://docs.github.com/en/github/authenticating-to-github/connecting-to-github-with-ssh). The instructions here lead you to:
#
# We'll overview what you will do before going through step by step instructions.
#
# 1. Setup:
#     1. Fork the class repository. Some directions in [fork-a-repo](https://docs.github.com/en/github/getting-started-with-github/fork-a-repo).
#     1. Create a directory on your personal system where you will keep all course materials.
#     1. In that directory, clone your fork of the repository.
#     1. Using `git remote`, make the class repo your `origin` and point its push address at your fork, so you can pull from the class and push to your fork.
#
# 1. Submission:
#     1. Copy your solutions into the appropriate directory (e.g. into `Labs/Lab.2/`) and with appropriate filename `Lab.2.solution.ipynb`.
#     1. Commit / push your solutions.
#
# Below are step by step instructions with examples (including example directory naming convention). Feel free to modify things as you see fit.
#
# #### Setup
# You should only need to follow this instructions once. Here are some useful git commands:
#
# * Git help: `git help`
# * Git remote help: `git help remote`
# * Check remote status: `git remote -v`
# * Add a remote: `git remote add <stream name> <repo URL>`
# * Remove a remote: `git remote remove <stream name>`
#
# Steps:
# 1. In a browser, log into GitHub and navigate to the [course repository](https://github.com/UTA-DataScience/DATA3402.Fall.2026).
# 1. On the top right of the page, press the fork button to create a new fork into your own GitHub account.
# 1. After successful fork, you should find the browser showing your fork of the course repository. Use the green "Code" button to copy path to the repo into your the clipboard of your computer.
# 1. Open a shell on your personal computer.
# 1. If you have not done so already, create a new directory/folder where you will keep all course material to navigate to it. For example: `mkdir Data-3402` and `cd Data-3402`.
# 1. Clone your fork of the repository using `git clone` followed by the path you copied into your clipboard. (copy/paste) If you already cloned the class repository here in Lab 1, this stops with *destination path already exists*: don't clone again, and don't delete that folder. Go into it and carry on with the steps below. Its `git remote -v` will show the class repo rather than your fork, and that is fine; the `set-url --push` step uses the fork URL you just copied.
# 1. Paste the URL to your fork in the worksheet for the TAs and instructors.
# 1. Now go into the directory of your clone (`cd DATA3402.Fall.2026`).
# 1. Type `git remote -v` to see the current setup for fetch and push.
# 1. Note the URL you see. This should be the same as what you used for your clone for both push and fetch.
# 1. Delete the origin remote using `git remote remove origin`.
# 1. Add the course repo as your remote using `git remote add origin https://github.com/UTA-DataScience/DATA3402.Fall.2026.git`.
# 1. Change the push to point to your fork. This means you will need the URL to your clone we copied earlier and confirmed as the original origin. The command will look something like: `git remote set-url --push origin  https://github.com/XXXXXX/DATA3402.Fall.2026.git`, where XXXXX is your username on GitHub.
# 1. Note that if you setup everything correctly, you now should be able to do `git pull` to get updates from the course repo, and do `git push` to push your commits into your own fork.
#
# ### Submission
# These instructions outline how you submit files. Some useful commands:
# * To add a file to local repository: `git add <file>`.
# * To commit all changed files into local repository: `git commit -a -m "A message"`. You need to provide some comment when you commit.
# * To push the commited files from the local repository to GitHub: `git push`.
# * To get updates from GitHub: `git pull`.
#
# Steps:
# 1. To submit your labs, navigate to your clone of your fork of the course repository.
# 1. Use `git pull` to make sure you have the latest updates.
# 1. Make sure your copy of the lab your are working on is in the appropriate place in this clone. That means if you have the file elsewhere, copy it to the same directory in your clone of your fork.
# 1. Do this **as soon as you pull a new lab, before you write anything** — not just before submitting: copy it to a name we never handed out, e.g. `cp Lab.2.ipynb Lab.2.solution.ipynb`, and work only in the copy from then on. `git pull` only touches filenames it recognizes from the class repo, so a copy under a new name can never conflict with an update we push later, even mid-week. If you already started editing `Lab.2.ipynb` directly, copy it now and switch over.
# 1. Add any files you wish to submit into the repo. For example: `git add Labs/Lab.2/Lab.2.solution.ipynb`
# 1. Commit any changes: `git commit -a -m "Lab 2 updates"`
# 1. Push your changes: `git push`
# 1. Check on github website that your solutions have been properly submitted.
#
# Before you leave today's session, make sure your GitHub repo is set up. If you need to work further on your lab, navigate jupyter to the copy of the lab you just submitted and work there. Once done, repeat the commit and push commands to submit your updated solution.
#
# Note that lab 2 is due by midnight Friday 9/11/2026.
#
# ---
#
# ## Part 2 — Object Oriented Programming exercises
#
# The rest of this notebook is the lab itself. It uses the classes material from Lectures 8 and 9,
# so start it after those; the submission setup above is what we do in the session.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, maximum):
        self.value = 0
        self.maximum = maximum

    def increment(self):
        if self.value < self.maximum:
            self.value += 1
        else:
            print("Error: Counter has reached the maximum value.")

    def reset(self):
        self.value = 0

# %%
counter = Counter(2)

print("Starting value:", counter.value)

counter.increment()
print("After increment:", counter.value)

counter.increment()
print("At maximum:", counter.value)

counter.increment()

counter.reset()
print("After reset:", counter.value)
# Out:
# Starting value: 0
# After increment: 1
# At maximum: 2
# Error: Counter has reached the maximum value.
# After reset: 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, maximum):
        self.__value = 0
        self.__maximum = maximum

    def increment(self):
        if self.__value < self.__maximum:
            self.__value += 1
        else:
            print("Error: Counter has reached the maximum value.")

    def reset(self):
        self.__value = 0

    def get_value(self):
        return self.__value

    def get_maximum(self):
        return self.__maximum

    def is_at_maximum(self):
        return self.__value == self.__maximum

# %%
counter = Counter(2)

print("Value:", counter.get_value())
print("Maximum:", counter.get_maximum())

counter.increment()
counter.increment()

print("Value after increments:", counter.get_value())
print("At maximum:", counter.is_at_maximum())

counter.reset()
print("After reset:", counter.get_value())
# Out:
# Value: 0
# Maximum: 2
# Value after increments: 2
# At maximum: True
# After reset: 0

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and provide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %%
rectangle = Rectangle(5, 3, 2, 4)

print("Length:", rectangle.get_length())
print("Width:", rectangle.get_width())
print("Position:", rectangle.get_x(), rectangle.get_y())
print("Area:", rectangle.area())
print("Perimeter:", rectangle.perimeter())
# Out:
# Length: 5
# Width: 3
# Position: 2 4
# Area: 15
# Perimeter: 16

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the circle. Make all data members private and provide accessors to retrieve values of data members.

# %%
import math

class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %%
circle = Circle(5, 2, 3)

print("Radius:", circle.get_radius())
print("Center x:", circle.get_x())
print("Center y:", circle.get_y())

print("Area:", circle.area())
print("Perimeter:", circle.perimeter())
# Out:
# Radius: 5
# Center x: 2
# Center y: 3
# Area: 78.53981633974483
# Perimeter: 31.41592653589793

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your rectangle and circle classes to inherit from the base class and overload the functions accordingly.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


rectangle = Rectangle(4, 3, 2, 2)
circle = Circle(3, 5, 5)

print("Rectangle is a Shape:", isinstance(rectangle, Shape))
print("Circle is a Shape:", isinstance(circle, Shape))

print("\nRectangle:")
print("Area:", rectangle.area())
print("Perimeter:", rectangle.perimeter())

print("\nCircle:")
print("Area:", circle.area())
print("Perimeter:", circle.perimeter())
# Out:
# Rectangle is a Shape: True
# Circle is a Shape: True
#
# Rectangle:
# Area: 12
# Perimeter: 14
#
# Circle:
# Area: 28.274333882308138
# Perimeter: 18.84955592153876

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    def __init__(self, x1, y1, x2, y2, x3, y3):
        self.__x1 = x1
        self.__y1 = y1
        self.__x2 = x2
        self.__y2 = y2
        self.__x3 = x3
        self.__y3 = y3

    def area(self):
        return abs(
            self.__x1 * (self.__y2 - self.__y3)
            + self.__x2 * (self.__y3 - self.__y1)
            + self.__x3 * (self.__y1 - self.__y2)
        ) / 2

    def perimeter(self):
        side1 = math.sqrt((self.__x2-self.__x1)**2 + (self.__y2-self.__y1)**2)
        side2 = math.sqrt((self.__x3-self.__x2)**2 + (self.__y3-self.__y2)**2)
        side3 = math.sqrt((self.__x1-self.__x3)**2 + (self.__y1-self.__y3)**2)

        return side1 + side2 + side3

    def get_x1(self):
        return self.__x1

    def get_y1(self):
        return self.__y1

    def get_x2(self):
        return self.__x2

    def get_y2(self):
        return self.__y2

    def get_x3(self):
        return self.__x3

    def get_y3(self):
        return self.__y3


triangle = Triangle(0, 0, 4, 0, 0, 3)

print("Point 1:", triangle.get_x1(), triangle.get_y1())
print("Point 2:", triangle.get_x2(), triangle.get_y2())
print("Point 3:", triangle.get_x3(), triangle.get_y3())

print("Area:", triangle.area())
print("Perimeter:", triangle.perimeter())
# Out:
# Point 1: 0 0
# Point 2: 4 0
# Point 3: 0 3
# Area: 6.0
# Perimeter: 12.0

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the perimeter of the object.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def perimeter_points(self):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def perimeter_points(self):
        x = self.__x
        y = self.__y
        l = self.__length
        w = self.__width

        return [
            (x, y),
            (x + l/4, y),
            (x + l/2, y),
            (x + 3*l/4, y),
            (x + l, y),
            (x + l, y + w/4),
            (x + l, y + w/2),
            (x + l, y + 3*w/4),
            (x + l, y + w),
            (x + 3*l/4, y + w),
            (x + l/2, y + w),
            (x + l/4, y + w),
            (x, y + w),
            (x, y + 3*w/4),
            (x, y + w/2),
            (x, y + w/4)
        ]


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def perimeter_points(self):
        points = []

        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))

        return points


class Triangle(Shape):
    def __init__(self, x1, y1, x2, y2, x3, y3):
        self.__x1 = x1
        self.__y1 = y1
        self.__x2 = x2
        self.__y2 = y2
        self.__x3 = x3
        self.__y3 = y3

    def area(self):
        return abs(
            self.__x1 * (self.__y2 - self.__y3)
            + self.__x2 * (self.__y3 - self.__y1)
            + self.__x3 * (self.__y1 - self.__y2)
        ) / 2

    def perimeter(self):
        side1 = math.sqrt((self.__x2-self.__x1)**2 + (self.__y2-self.__y1)**2)
        side2 = math.sqrt((self.__x3-self.__x2)**2 + (self.__y3-self.__y2)**2)
        side3 = math.sqrt((self.__x1-self.__x3)**2 + (self.__y1-self.__y3)**2)

        return side1 + side2 + side3

    def get_x1(self):
        return self.__x1

    def get_y1(self):
        return self.__y1

    def get_x2(self):
        return self.__x2

    def get_y2(self):
        return self.__y2

    def get_x3(self):
        return self.__x3

    def get_y3(self):
        return self.__y3

    def perimeter_points(self):
        points = []

        vertices = [
            (self.__x1, self.__y1),
            (self.__x2, self.__y2),
            (self.__x3, self.__y3)
        ]

        for i in range(3):
            x1, y1 = vertices[i]
            x2, y2 = vertices[(i + 1) % 3]

            for j in range(5):
                t = j / 5
                x = x1 + t * (x2 - x1)
                y = y1 + t * (y2 - y1)
                points.append((x, y))

        return points


rectangle = Rectangle(4, 3, 2, 2)
circle = Circle(3, 5, 5)
triangle = Triangle(0, 0, 4, 0, 0, 3)

print("Rectangle perimeter points:")
print(rectangle.perimeter_points())
print("Number of points:", len(rectangle.perimeter_points()))

print("\nCircle perimeter points:")
print(circle.perimeter_points())
print("Number of points:", len(circle.perimeter_points()))

print("\nTriangle perimeter points:")
print(triangle.perimeter_points())
print("Number of points:", len(triangle.perimeter_points()))
# Out:
# Rectangle perimeter points:
# [(2, 2), (3.0, 2), (4.0, 2), (5.0, 2), (6, 2), (6, 2.75), (6, 3.5), (6, 4.25), (6, 5), (5.0, 5), (4.0, 5), (3.0, 5), (2, 5), (2, 4.25), (2, 3.5), (2, 2.75)]
# Number of points: 16
#
# Circle perimeter points:
# [(8.0, 5.0), (7.77163859753386, 6.148050297095269), (7.121320343559643, 7.121320343559642), (6.14805029709527, 7.77163859753386), (5.0, 8.0), (3.8519497029047307, 7.77163859753386), (2.8786796564403576, 7.121320343559643), (2.22836140246614, 6.14805029709527), (2.0, 5.0), (2.2283614024661396, 3.851949702904731), (2.878679656440357, 2.8786796564403576), (3.851949702904729, 2.2283614024661405), (4.999999999999999, 2.0), (6.14805029709527, 2.22836140246614), (7.121320343559642, 2.878679656440357), (7.77163859753386, 3.851949702904729)]
# Number of points: 16
#
# Triangle perimeter points:
# [(0.0, 0.0), (0.8, 0.0), (1.6, 0.0), (2.4, 0.0), (3.2, 0.0), (4.0, 0.0), (3.2, 0.6000000000000001), (2.4, 1.2000000000000002), (1.6, 1.7999999999999998), (0.7999999999999998, 2.4000000000000004), (0.0, 3.0), (0.0, 2.4), (0.0, 1.7999999999999998), (0.0, 1.2000000000000002), (0.0, 0.5999999999999996)]
# Number of points: 15

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def perimeter_points(self):
        raise NotImplementedError

    def contains(self, x, y):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def perimeter_points(self):
        x = self.__x
        y = self.__y
        l = self.__length
        w = self.__width

        return [
            (x, y),
            (x + l/4, y),
            (x + l/2, y),
            (x + 3*l/4, y),
            (x + l, y),
            (x + l, y + w/4),
            (x + l, y + w/2),
            (x + l, y + 3*w/4),
            (x + l, y + w),
            (x + 3*l/4, y + w),
            (x + l/2, y + w),
            (x + l/4, y + w),
            (x, y + w),
            (x, y + 3*w/4),
            (x, y + w/2),
            (x, y + w/4)
        ]

    def contains(self, x, y):
        return (
            self.__x <= x <= self.__x + self.__length
            and self.__y <= y <= self.__y + self.__width
        )


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def perimeter_points(self):
        points = []

        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))

        return points

    def contains(self, x, y):
        return (
            (x - self.__x)**2 +
            (y - self.__y)**2
            <= self.__radius**2
        )


class Triangle(Shape):
    def __init__(self, x1, y1, x2, y2, x3, y3):
        self.__x1 = x1
        self.__y1 = y1
        self.__x2 = x2
        self.__y2 = y2
        self.__x3 = x3
        self.__y3 = y3

    def area(self):
        return abs(
            self.__x1 * (self.__y2 - self.__y3)
            + self.__x2 * (self.__y3 - self.__y1)
            + self.__x3 * (self.__y1 - self.__y2)
        ) / 2

    def perimeter(self):
        side1 = math.sqrt((self.__x2-self.__x1)**2 + (self.__y2-self.__y1)**2)
        side2 = math.sqrt((self.__x3-self.__x2)**2 + (self.__y3-self.__y2)**2)
        side3 = math.sqrt((self.__x1-self.__x3)**2 + (self.__y1-self.__y3)**2)

        return side1 + side2 + side3

    def get_x1(self):
        return self.__x1

    def get_y1(self):
        return self.__y1

    def get_x2(self):
        return self.__x2

    def get_y2(self):
        return self.__y2

    def get_x3(self):
        return self.__x3

    def get_y3(self):
        return self.__y3

    def perimeter_points(self):
        points = []

        vertices = [
            (self.__x1, self.__y1),
            (self.__x2, self.__y2),
            (self.__x3, self.__y3)
        ]

        for i in range(3):
            x1, y1 = vertices[i]
            x2, y2 = vertices[(i + 1) % 3]

            for j in range(5):
                t = j / 5
                x = x1 + t * (x2 - x1)
                y = y1 + t * (y2 - y1)
                points.append((x, y))

        return points

    def contains(self, x, y):
        def sign(px, py, ax, ay, bx, by):
            return (px-bx)*(ay-by) - (ax-bx)*(py-by)

        d1 = sign(x, y, self.__x1, self.__y1,
                  self.__x2, self.__y2)

        d2 = sign(x, y, self.__x2, self.__y2,
                  self.__x3, self.__y3)

        d3 = sign(x, y, self.__x3, self.__y3,
                  self.__x1, self.__y1)

        has_negative = d1 < 0 or d2 < 0 or d3 < 0
        has_positive = d1 > 0 or d2 > 0 or d3 > 0

        return not (has_negative and has_positive)


rectangle = Rectangle(4, 3, 2, 2)
circle = Circle(3, 5, 5)
triangle = Triangle(0, 0, 4, 0, 0, 3)

print("Rectangle:")
print("Point (3, 3):", rectangle.contains(3, 3))
print("Point (20, 20):", rectangle.contains(20, 20))

print("\nCircle:")
print("Point (5, 5):", circle.contains(5, 5))
print("Point (20, 20):", circle.contains(20, 20))

print("\nTriangle:")
print("Point (1, 1):", triangle.contains(1, 1))
print("Point (5, 5):", triangle.contains(5, 5))
# Out:
# Rectangle:
# Point (3, 3): True
# Point (20, 20): False
#
# Circle:
# Point (5, 5): True
# Point (20, 20): False
#
# Triangle:
# Point (1, 1): True
# Point (5, 5): False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def perimeter_points(self):
        raise NotImplementedError

    def contains(self, x, y):
        raise NotImplementedError

    def overlaps(self, other):
        for x, y in self.perimeter_points():
            if other.contains(x, y):
                return True

        for x, y in other.perimeter_points():
            if self.contains(x, y):
                return True

        return False


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def perimeter_points(self):
        x = self.__x
        y = self.__y
        l = self.__length
        w = self.__width

        return [
            (x, y),
            (x + l/4, y),
            (x + l/2, y),
            (x + 3*l/4, y),
            (x + l, y),
            (x + l, y + w/4),
            (x + l, y + w/2),
            (x + l, y + 3*w/4),
            (x + l, y + w),
            (x + 3*l/4, y + w),
            (x + l/2, y + w),
            (x + l/4, y + w),
            (x, y + w),
            (x, y + 3*w/4),
            (x, y + w/2),
            (x, y + w/4)
        ]

    def contains(self, x, y):
        return (
            self.__x <= x <= self.__x + self.__length
            and self.__y <= y <= self.__y + self.__width
        )


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def perimeter_points(self):
        points = []

        for i in range(16):
            angle = 2 * math.pi * i / 16
            x = self.__x + self.__radius * math.cos(angle)
            y = self.__y + self.__radius * math.sin(angle)
            points.append((x, y))

        return points

    def contains(self, x, y):
        return (
            (x - self.__x)**2 +
            (y - self.__y)**2
            <= self.__radius**2
        )


class Triangle(Shape):
    def __init__(self, x1, y1, x2, y2, x3, y3):
        self.__x1 = x1
        self.__y1 = y1
        self.__x2 = x2
        self.__y2 = y2
        self.__x3 = x3
        self.__y3 = y3

    def area(self):
        return abs(
            self.__x1 * (self.__y2 - self.__y3)
            + self.__x2 * (self.__y3 - self.__y1)
            + self.__x3 * (self.__y1 - self.__y2)
        ) / 2

    def perimeter(self):
        side1 = math.sqrt((self.__x2-self.__x1)**2 + (self.__y2-self.__y1)**2)
        side2 = math.sqrt((self.__x3-self.__x2)**2 + (self.__y3-self.__y2)**2)
        side3 = math.sqrt((self.__x1-self.__x3)**2 + (self.__y1-self.__y3)**2)

        return side1 + side2 + side3

    def get_x1(self):
        return self.__x1

    def get_y1(self):
        return self.__y1

    def get_x2(self):
        return self.__x2

    def get_y2(self):
        return self.__y2

    def get_x3(self):
        return self.__x3

    def get_y3(self):
        return self.__y3

    def perimeter_points(self):
        points = []

        vertices = [
            (self.__x1, self.__y1),
            (self.__x2, self.__y2),
            (self.__x3, self.__y3)
        ]

        for i in range(3):
            x1, y1 = vertices[i]
            x2, y2 = vertices[(i + 1) % 3]

            for j in range(5):
                t = j / 5
                x = x1 + t * (x2 - x1)
                y = y1 + t * (y2 - y1)
                points.append((x, y))

        return points

    def contains(self, x, y):
        def sign(px, py, ax, ay, bx, by):
            return (px-bx)*(ay-by) - (ax-bx)*(py-by)

        d1 = sign(x, y, self.__x1, self.__y1,
                  self.__x2, self.__y2)

        d2 = sign(x, y, self.__x2, self.__y2,
                  self.__x3, self.__y3)

        d3 = sign(x, y, self.__x3, self.__y3,
                  self.__x1, self.__y1)

        has_negative = d1 < 0 or d2 < 0 or d3 < 0
        has_positive = d1 > 0 or d2 > 0 or d3 > 0

        return not (has_negative and has_positive)


rectangle1 = Rectangle(4, 4, 2, 2)
rectangle2 = Rectangle(4, 4, 4, 4)
rectangle3 = Rectangle(2, 2, 20, 20)

print("Rectangle 1 overlaps Rectangle 2:")
print(rectangle1.overlaps(rectangle2))

print("\nRectangle 1 overlaps Rectangle 3:")
print(rectangle1.overlaps(rectangle3))

circle = Circle(3, 4, 4)

print("\nRectangle 1 overlaps Circle:")
print(rectangle1.overlaps(circle))
# Out:
# Rectangle 1 overlaps Rectangle 2:
# True
#
# Rectangle 1 overlaps Rectangle 3:
# False
#
# Rectangle 1 overlaps Circle:
# True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture into a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
from paint import Canvas, Rectangle, Circle, Triangle, CompoundShape

canvas = Canvas(40, 20)

rectangle = Rectangle(5, 10, 2, 2)
circle = Circle(3, 10, 20)
triangle = Triangle(12, 5, 17, 10, 12, 15)

drawing = CompoundShape()

drawing.add_shape(rectangle)
drawing.add_shape(circle)
drawing.add_shape(triangle)

print("CompoundShape created:", isinstance(drawing, CompoundShape))
print("Rectangle created:", isinstance(rectangle, Rectangle))
print("Circle created:", isinstance(circle, Circle))
print("Triangle created:", isinstance(triangle, Triangle))

drawing.paint(canvas)

print("\nCompound shape drawing:")
canvas.display()
# Out:
# CompoundShape created: True
# Rectangle created: True
# Circle created: True
# Triangle created: True
#
# Compound shape drawing:
#
#
#   **********
#   *        *
#   *        *
#   *        *
#   *        *
#   **********       ooo
#                   o   o
#                  o     o
#                  o     o
#                  o     o
#      + + + + + +  o   o
#       +       +    ooo
#        +     +
#         +   +
#          + +
#           +

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
from paint import Canvas, Rectangle, Circle, Triangle, RasterDrawing

drawing = RasterDrawing()

rectangle = Rectangle(5, 10, 2, 2)
circle = Circle(3, 10, 20)
triangle = Triangle(12, 5, 17, 10, 12, 15)

drawing.add_shape(rectangle)
drawing.add_shape(circle)
drawing.add_shape(triangle)

print("RasterDrawing created:", isinstance(drawing, RasterDrawing))
print("Rectangle created:", isinstance(rectangle, Rectangle))
print("Circle created:", isinstance(circle, Circle))
print("Triangle created:", isinstance(triangle, Triangle))

canvas1 = Canvas(40, 20)

print("\nOriginal drawing:")
drawing.paint(canvas1)
canvas1.display()

drawing.remove_shape(circle)

canvas2 = Canvas(40, 20)

print("\nModified drawing after removing circle:")
drawing.paint(canvas2)
canvas2.display()
# Out:
# RasterDrawing created: True
# Rectangle created: True
# Circle created: True
# Triangle created: True
#
# Original drawing:
#
#
#   **********
#   *        *
#   *        *
#   *        *
#   *        *
#   **********       ooo
#                   o   o
#                  o     o
#                  o     o
#                  o     o
#      + + + + + +  o   o
#       +       +    ooo
#        +     +
#         +   +
#          + +
#           +
#
#
#
# Modified drawing after removing circle:
#
#
#   **********
#   *        *
#   *        *
#   *        *
#   *        *
#   **********
#
#
#
#
#      + + + + + +
#       +       +
#        +     +
#         +   +
#          + +
#           +

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstrate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
from paint import Canvas, Rectangle, Circle, Triangle, RasterDrawing, load_raster_drawing

canvas = Canvas(40, 20)

drawing = RasterDrawing()
drawing.add_shape(Rectangle(5, 10, 2, 2))
drawing.add_shape(Circle(3, 10, 20))
drawing.add_shape(Triangle(12, 5, 17, 10, 12, 15))

drawing.save("drawing.txt")

loaded_drawing = load_raster_drawing("drawing.txt")

print("Loaded drawing:")
loaded_drawing.paint(canvas)
canvas.display()
# Out:
# Loaded drawing:
#
#
#   **********
#   *        *
#   *        *
#   *        *
#   *        *
#   **********       ooo
#                   o   o
#                  o     o
#                  o     o
#                  o     o
#      + + + + + +  o   o
#       +       +    ooo
#        +     +
#         +   +
#          + +
#           +
